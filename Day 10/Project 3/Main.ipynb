# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer = pd.read_csv("customers.csv")
employee = pd.read_csv("employees.csv")
product = pd.read_csv("products.csv")
order = pd.read_csv("orders.csv")
review = pd.read_csv("reviews.csv")

# %%
print(customer.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  512 non-null    object
#  1   name         485 non-null    object
#  2   age          512 non-null    int64
#  3   gender       512 non-null    object
#  4   city         492 non-null    object
#  5   signup_date  512 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 24.1+ KB
# None

# %%
customer.isnull().sum()
# Out:
# customer_id     0
# name           27
# age             0
# gender          0
# city           20
# signup_date     0
# dtype: int64

# %%
customer.count()
# Out:
# customer_id    512
# name           485
# age            512
# gender         512
# city           492
# signup_date    512
# dtype: int64

# %%
customer=customer.dropna()

# %%
customer.isnull().sum()
# Out:
# customer_id    0
# name           0
# age            0
# gender         0
# city           0
# signup_date    0
# dtype: int64

# %%
customer['gender'].unique()
# Out:
# array(['FEMALE', 'MALE', 'Male', 'male', 'Female', 'female'], dtype=object)

# %%
customer['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
customer.head()
# Out:
#   customer_id     name  age  gender        city signup_date
# 0       C0001   AYESHA   19  FEMALE  rawalpindi  2023-04-03
# 1       C0002  hassan    24    MALE     Sialkot  2024-05-14
# 2       C0003    Sara    19    Male  Rawalpindi  2023-04-22
# 3       C0004   Shayan   56    male       swabi  2023-02-12
# 4       C0005   Muneeb   44    Male      Quetta  2025-04-21

# %%
customer['gender']=customer['gender'].str.capitalize()
customer['name'] = customer['name'].str.strip().str.capitalize()

# %%
customer.isnull().sum()
# Out:
# customer_id     0
# name           27
# age             0
# gender          0
# city           20
# signup_date     0
# dtype: int64

# %%
customer=customer.dropna()

# %%
customer.isnull().sum()
# Out:
# customer_id    0
# name           0
# age            0
# gender         0
# city           0
# signup_date    0
# dtype: int64

# %%
customer.head()
# Out:
#   customer_id    name  age  gender        city signup_date
# 0       C0001  Ayesha   19  Female  rawalpindi  2023-04-03
# 1       C0002  Hassan   24    Male     Sialkot  2024-05-14
# 2       C0003    Sara   19    Male  Rawalpindi  2023-04-22
# 3       C0004  Shayan   56    Male       swabi  2023-02-12
# 4       C0005  Muneeb   44    Male      Quetta  2025-04-21

# %%
print((customer['signup_date'].dtype))
# Out:
# object

# %%
customer['signup_date'] = pd.to_datetime(customer['signup_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 customer['signup_date'] = pd.to_datetime(customer['signup_date'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "2022/09/13" doesn't match format "%Y-%m-%d", at position 7. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
