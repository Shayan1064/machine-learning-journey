# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('employee_data.csv')

# %%
df.head()
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
sns.scatterplot(
    data=df,
    x='Age',
    y='Salary',
    hue='Department'
)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.lineplot(
    data=df,
    x='Age',
    y='Salary',
    hue='Department'
)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.barplot(
    data=df,
    x='Department',
    y='Salary'
)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
sns.boxplot(
    data=df,
    x='Salary'
)
# Out:
# <Axes: xlabel='Salary'>

# %%
df['Salary'].unique()
# Out:
# array([55000, 72000, 48000, 91000, 65000, 50000, 82000, 47000, 75000,
#        60000])

# %%
df['Salary']=df['Salary'].replace(91000,)
